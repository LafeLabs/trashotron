# %% [markdown]
# # PLOTS OF SLIME DATA

# %%
import requests
import json
import matplotlib.pyplot as plt
# Fetch the JSON data from the URL
url = "https://raw.githubusercontent.com/LafeLabs/trashotron/main/slimedata/json_data_array1681490882.txt"
response = requests.get(url)
data = json.loads(response.text)
spectra = []
for obj in data:
    spectrum = np.array(obj["spectrum"])
    spectra.append(spectrum)

    
spectra_2d = np.vstack(spectra)
fig, ax = plt.subplots(figsize=(14, 8))
im = ax.imshow(spectra_2d.T[:][:-900], aspect="auto", origin="lower")
ax.set_xlabel("Index of top-level array")
ax.set_ylabel("Index of spectrum array")
ax.set_title("Spectrum data")
fig.colorbar(im)
plt.show()

# %%
z_values = [obj['y'] for obj in data]

# Plot the 'z' values
plt.plot(z_values)
plt.xlabel("Index of top-level array")
plt.ylabel("Value of 'z'")
plt.title("Values of 'z'")
plt.show()

# %%
data[10]['z']
# Out:
# 0.03333333333333333

# %%
import requests
import json
import matplotlib.pyplot as plt
# Fetch the JSON data from the URL
url = "https://raw.githubusercontent.com/LafeLabs/trashotron/main/slimedata/json_data_array1681596779.txt"
response = requests.get(url)
data = json.loads(response.text)
spectra = []
for obj in data:
    spectrum = np.array(obj["spectrum"])
    spectra.append(spectrum)

    
spectra_2d = np.vstack(spectra)
fig, ax = plt.subplots(figsize=(14, 8))
im = ax.imshow(spectra_2d.T[:][:-900], aspect="auto", origin="lower")
ax.set_xlabel("Index of top-level array")
ax.set_ylabel("Index of spectrum array")
ax.set_title("Spectrum data")
fig.colorbar(im)
plt.show()
